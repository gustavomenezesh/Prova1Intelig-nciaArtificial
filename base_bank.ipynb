# %%
import pandas as pd
from sklearn import preprocessing

base = pd.read_csv('train.csv', encoding = "ISO-8859-1")
print(base)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
le = preprocessing.LabelEncoder()
for column in base.columns:
    if base[column].dtypes == 'object':
        base[column] = le.fit_transform(base[column])
        
print(base)
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 0        5      8       261         1     -1         0         3  0
# 1        5      8       151         1     -1         0         3  0
# 2        5      8        76         1     -1         0         3  0
# 3        5      8        92         1     -1         0         3  0
# 4        5      8       198         1     -1         0         3  0
# ...    ...    ...       ...       ...    ...       ...       ... ..
# 45206   17      9       977         3     -1         0         3  1
# 45207   17      9       456         2     -1         0         3  1
# 45208   17      9      1127         5    184         3         2  1
# 45209   17      9       508         4     -1         0         3  0
# 45210   17      9       361         2    188        11         1  0
#
# [45211 rows x 17 columns]

# %%
corr = base.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col1 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col4 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col5 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col7 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col8 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col9 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col10 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col11 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col12 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col13 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col14 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col15 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row0_col16 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col0 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col2 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col3 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col4 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col5 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col6 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col7 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col8 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col9 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col10 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col11 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col12 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col13 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col14 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col15 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row1_col16 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col1 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col3 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col4 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col5 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col6 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col8 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col9 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col10 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col11 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col12 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col13 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col14 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col15 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row2_col16 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row3_col0 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row3_col1 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row3_col2 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row3_col4 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row3_col5 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row3_col6 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row3_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_f8e4c792_1cc1_11eb_90be_6432a8958796row3_col8 {
#             background-color:  #5b7ae5;
